# %%
import os
import dotenv
import sqlalchemy
import pandas as pd

dotenv.load_dotenv(override=True, dotenv_path="credenziali.env")

username = os.getenv("username")
password = os.getenv("password")
host = os.getenv("host")
dbname = os.getenv("dbname")

connection_string = "mysql+pymysql://" + username + ":" + password + "@" + host + "/" + dbname
print(username, password, host, dbname)
db_engine = sqlalchemy.create_engine(connection_string)
query = "SELECT * FROM dimproduct"
pd.read_sql(query, db_engine)
# Out:
# studente_dapt Ep1c0d3!!D4t4**4n4lys1s epicode-data-pt-mysql.cvetyjye2qbl.eu-central-1.rds.amazonaws.com AdventureWorksDW
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0             1             AR-5381                    NaN
# 1             2             BA-8327                    NaN
# 2             3             BE-2349                    NaN
# 3             4             BE-2908                    NaN
# 4             5             BL-2036                    NaN
# ..          ...                 ...                    ...
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# ...

# %%
#Esercizio 4 - Amazon
import pandas as pd

# %%
df= pd.read_csv('amazon.csv') #creo un dataframe usando o metodo read di pandas

# %%
print(df.shape)  #cosi capisco quanto grande è il dataset, la sua dimensione. Numero di righe e colonne
# Out:
# (20000, 2)

# %%
print(df.columns) #leggendo i nome delle colonne
# Out:
# Index(['reviewText', 'Positive'], dtype='object')

# %%
print(df.head(10)) # leggendo le 10 prime righe
# Out:
#                                           reviewText  Positive
# 0  This is a one of the best apps acording to a b...         1
# 1  This is a pretty good version of the game for ...         1
# 2  this is a really cool game. there are a bunch ...         1
# 3  This is a silly game and can be frustrating, b...         1
# 4  This is a terrific game on any pad. Hrs of fun...         1
# 5  This is a very entertaining game!  You don't h...         1
# 6  this is awesome and you don't need wi ti to pl...         1
# 7  this is awesome I bet no one even reads the re...         1
# 8  This is basicly the free version but with ads....         1
# 9  this is by far the best free app that is avail...         1

# %%
print(df.sample(10)) # leggendo 10 righe a caso
# Out:
#                                               reviewText  Positive
# 17535  It did not like this because it just didn't se...         0
# 7515   Rate it a 5 will all ways  enjoy closer to you...         1
# 9692   I think this game is awesome and totally worth...         1
# 14380  The electronic quarterlyis very helpful to stu...         1
# 4541   I'm not very good at cross words so it's not a...         1
# 905    Majesty is a very fun and adicting game.  i tr...         1
# 616    It is a lot of fun the kids really enjoy this ...         1
# 579    By boys promised I would like  Angry Birds, an...         1
# 18308  This app is a waste of time, and very wired. I...         0
# 2878   In app purchase on a 4.99 application.Are you ...         0

# %%
df['Positive'].value_counts() #controllando le recensione, se vede che la maggior parte è positva
# Out:
# Positive
# 1    15233
# 0     4767
# Name: count, dtype: int64

# %%
#Esercizio 5 - Diabetes

# %%
df=pd.read_csv('diabetes.csv')

# %%
df.shape #controllo la dimenzione
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['Number of times pregnant',
#        'Plasma glucose concentration a 2 hours in an oral glucose tolerance test',
#        'Diastolic blood pressure (mm Hg)', 'Triceps skin fold thickness (mm)',
#        '2-Hour serum insulin (mu U/ml)',
#        'Body mass index (weight in kg/(height in m)^2)',
#        'Diabetes pedigree function', 'Age (years)', 'Class variable'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
df.describe() #misura estatitistica dei numeri
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# ...

# %%
#selezionando fascia di età usando il filtro loc

fascia_20_29= df.loc[(df['Age (years)'] >=20) & (df['Age (years)'] <=29)]
fascia_20_29.shape
# Out:
# (396, 9)

# %%
#selezionando fascia di età usando il filtro loc

fascia_30_39= df.loc[(df['Age (years)'] >=30) & (df['Age (years)'] <=39)]
fascia_30_39.shape
# Out:
# (165, 9)

# %%
#selezionando fascia di età usando il filtro loc

fascia_40_50= df.loc[(df['Age (years)'] >=40) & (df['Age (years)'] <=50)]
fascia_40_50.shape
# Out:
# (126, 9)

# %%
# controllando il percentuale di ogni fascia etaria

totale=len(df)
print('Tot_paziente:',totale)
# Out:
# Tot_paziente: 768

# %%
totale=len(df)
print("Tot_paziente:", totale)

percentuale_20_29 = (len(fascia_20_29)) / totale * 100
percentuale_30_39 = (len(fascia_30_39)) / totale * 100
percentuale_40_50 = (len(fascia_40_50)) / totale * 100
print("percentuale_20_29 anni:", percentuale_20_29)
print("percentuale_30_39 anni:", percentuale_30_39)
print("percentuale_40_50 anni:", percentuale_40_50)
# Out:
# Tot_paziente: 768
# percentuale_20_29 anni: 51.5625
# percentuale_30_39 anni: 21.484375
# percentuale_40_50 anni: 16.40625
