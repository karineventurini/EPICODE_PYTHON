# %%
# - 1 - Algoritmi di task quatidiani

# %%
# Task 1 - Passeggiare con il cane

print("1. Mettere il Capottino")
print("2. Mettere il guinzaglio")
print("3. Prendere i sacchetti")
print("4. Prendere l'acqua")
print("5. Scegliere il tragitto")
print("6. Uscire")
# Out:
# 1. Mettere il Capottino
# 2. Mettere il guinzaglio
# 3. Prendere i sacchetti
# 4. Prendere l'acqua
# 5. Scegliere il tragitto
# 6. Uscire

# %%
#  2 - 3 -4 - Creando una variabile, stampare, alterare.

# %%
studenti_iniciali = 25

# %%
nuovi_studenti = 3

# %%
totale_studenti = studenti_iniciali + nuovi_studenti
print(totale_studenti)
# Out:
# 28

# %%
# Creare variabile testo

# %%
istituto = "Epicode"
print(istituto)
# Out:
# Epicode

# %%
# Operazione con variabile

# %%
x = 10
x = x + 2
x = x * 3
print(x)
# Out:
# 36

# %%
# Creando stringhe e verificando la lunghezza

# %%
strl1 = "Windows"
strl2 = "Excel"
strl3 = "Powerpoint"
strl4 = "Word"

print(len(strl1))
print(len(strl2))
print(len(strl3))
print(len(strl4))
# Out:
# 7
# 5
# 10
# 4

# %%
# Calcolando i secondi

# %%
secondi_anno = 365*24*60*60
print(secondi_anno)
# Out:
# 31536000

# %%
# Usando upper e lower

# %%
my_string = "I am studing Python"
print(my_string)
# Out:
# I am studing Python

# %%
print(my_string.upper())
# Out:
# I AM STUDING PYTHON

# %%
print(my_string.lower())
# Out:
# i am studing python
